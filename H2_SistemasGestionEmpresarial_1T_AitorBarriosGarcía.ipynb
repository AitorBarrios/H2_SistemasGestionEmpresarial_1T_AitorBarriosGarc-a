# %%
#IMPORTAMOS EL TKINTER Y MOSTRAMOS NUESTRA VENTANA
import tkinter as tk
import sqlite3
from tkinter import PhotoImage,messagebox,ttk,Scrollbar,Label,Entry,Button
ventana = tk.Tk()
ventana.title("H2_SistemasGestionEmpresarial_1T_AitorBarriosGarcía")
ventana.resizable(False,False)
cat = tk.PhotoImage(file='G://Mi unidad//2ºDAM//Sistemas de Gestión Empresarial//HITOS//H2_SistemasGestionEmpresarial_1T_Aitor_BarriosGarcia//img//categoria.png').subsample(5,5)
cli = tk.PhotoImage(file='G://Mi unidad//2ºDAM//Sistemas de Gestión Empresarial//HITOS//H2_SistemasGestionEmpresarial_1T_Aitor_BarriosGarcia//img//cliente.png').subsample(15,15)
pro = tk.PhotoImage(file='G://Mi unidad//2ºDAM//Sistemas de Gestión Empresarial//HITOS//H2_SistemasGestionEmpresarial_1T_Aitor_BarriosGarcia//img//producto.png').subsample(5,5)
ped = tk.PhotoImage(file='G://Mi unidad//2ºDAM//Sistemas de Gestión Empresarial//HITOS//H2_SistemasGestionEmpresarial_1T_Aitor_BarriosGarcia//img//pedido.png').subsample(5,5)
det = tk.PhotoImage(file='G://Mi unidad//2ºDAM//Sistemas de Gestión Empresarial//HITOS//H2_SistemasGestionEmpresarial_1T_Aitor_BarriosGarcia//img//detalle.png').subsample(5,5)
"""cat = tk.PhotoImage(file='/Users/aitorbg/Library/CloudStorage/GoogleDrive-aitor.barrios@campusfp.es/Mi unidad/2ºDAM/Sistemas de Gestión Empresarial/HITOS/H2_SistemasGestionEmpresarial_1T_Aitor_BarriosGarcia/img/categoria.png').subsample(5,5)
cli = tk.PhotoImage(file='/Users/aitorbg/Library/CloudStorage/GoogleDrive-aitor.barrios@campusfp.es/Mi unidad/2ºDAM/Sistemas de Gestión Empresarial/HITOS/H2_SistemasGestionEmpresarial_1T_Aitor_BarriosGarcia/img/cliente.png').subsample(15,15)
pro = tk.PhotoImage(file='/Users/aitorbg/Library/CloudStorage/GoogleDrive-aitor.barrios@campusfp.es/Mi unidad/2ºDAM/Sistemas de Gestión Empresarial/HITOS/H2_SistemasGestionEmpresarial_1T_Aitor_BarriosGarcia/img/producto.png').subsample(5,5)
ped = tk.PhotoImage(file='/Users/aitorbg/Library/CloudStorage/GoogleDrive-aitor.barrios@campusfp.es/Mi unidad/2ºDAM/Sistemas de Gestión Empresarial/HITOS/H2_SistemasGestionEmpresarial_1T_Aitor_BarriosGarcia/img/pedido.png').subsample(5,5)
det = tk.PhotoImage(file='/Users/aitorbg/Library/CloudStorage/GoogleDrive-aitor.barrios@campusfp.es/Mi unidad/2ºDAM/Sistemas de Gestión Empresarial/HITOS/H2_SistemasGestionEmpresarial_1T_Aitor_BarriosGarcia/img/detalle.png').subsample(5,5)"""
ventana.geometry('800x800')

def vCat():
    def crear_reg():
        id_cat = entCat_id.get()
        nombre_cat = entCat_nombre.get()

        with sqlite3.connect("H2_SGE_1T_AitorBarriosGarcia.db") as conn:
            cursor = conn.cursor()

            cursor.execute("INSERT INTO categoria (id,nombre) VALUES (?,?)",(id_cat,nombre_cat))
            conn.commit()
            mostrar_reg()
            messagebox.showinfo("✔","Categoría Creada")

    def leer_reg():
        with sqlite3.connect("H2_SGE_1T_AitorBarriosGarcia.db") as conn:
            cursor = conn.cursor()
            cursor.execute("SELECT * FROM categoria")
            registros = cursor.fetchall()
        return registros
    
    def mostrar_reg():
        lista_reg.delete(*lista_reg.get_children())
        for registro in leer_reg():
            lista_reg.insert("","end",values=registro)

    def eliminar_reg():
        seleccion = lista_reg.selection()
        if seleccion:

            id_seleccionado = lista_reg.item(seleccion, "values")[0]
            with sqlite3.connect("H2_SGE_1T_AitorBarriosGarcia.db") as conn:
                cursor = conn.cursor()

                cursor.execute("DELETE FROM categoria WHERE id = ?", id_seleccionado)
                conn.commit()
                mostrar_reg()
                messagebox.showinfo("✔", "Categoria Eliminada")

    def modificar_reg():
        seleccion = lista_reg.selection()
        if seleccion:
            id_select = lista_reg.item(seleccion,"values")[0]

            nuevo_id=entCat_id.get()
            nuevo_nombre=entCat_nombre.get()

            with sqlite3.connect("H2_SGE_1T_AitorBarriosGarcia.db") as conn:
                cursor = conn.cursor()

                try:
                    cursor.execute("UPDATE categoria SET id=?,nombre=? where id=?",(nuevo_id,nuevo_nombre,id_select))
                    conn.commit()
                    mostrar_reg()
                    messagebox.showinfo("✔","Categoria Modificada")
                except sqlite3.Error as e:
                    messagebox.showerror("❌",f"No se pudo modificar: {e}")


    vCat = tk.Toplevel(ventana)
    vCat.title("Categoría")
    vCat.resizable(False,False)
    vCat.geometry("800x800")

    lblCat_id = tk.Label(vCat,text="ID")
    lblCat_id.grid(row=0,column=0,padx=10,pady=10)
    entCat_id = tk.Entry(vCat)
    entCat_id.grid(row=0,column=1)

    lblCat_nombre = tk.Label(vCat,text="Nombre")
    lblCat_nombre.grid(row=1,column=0,padx=10,pady=10)
    entCat_nombre = tk.Entry(vCat)
    entCat_nombre.grid(row=1,column=1)

    bt_crear = tk.Button(vCat,text="Crear",command=crear_reg)
    bt_crear.grid(row=2,column=0,padx=10,pady=10)
    bt_eliminar = tk.Button(vCat,text="Eliminar",command=eliminar_reg)
    bt_eliminar.grid(row=3,column=0,padx=10,pady=10)
    bt_modificar = tk.Button(vCat,text="Modificar",command=modificar_reg)
    bt_modificar.grid(row=4,column=0,padx=10,pady=10)

    lista_reg = ttk.Treeview(vCat,columns=("ID","Nombre"),show="headings",selectmode="browse")
    lista_reg.heading("ID",text="ID")
    lista_reg.heading("Nombre",text="Nombre")
    lista_reg.column("ID",width=100)
    lista_reg.column("Nombre",width=100)
    estilo=ttk.Style()
    estilo.configure("Treeview",background="gray",foreground="blue",rowheight=25)
    estilo.map("Treeview",background=[('selected','#cc007b')])
    lista_reg.grid(row=0, column=2, rowspan=6, padx=10, pady=10, sticky="nsew")
    scrollbar = Scrollbar(vCat, orient="vertical", command=lista_reg.yview)
    scrollbar.grid(row=0, column=3, rowspan=6, sticky="ns")
    lista_reg.configure(yscrollcommand=scrollbar.set)

    mostrar_reg()
    vCat.mainloop()

def vCli():
    def crear_reg():
        id_cli = entCli_id.get()
        nombre_cli = entCli_nombre.get()
        apellido_cli = entCli_apellido.get()
        telefono_cli = entCli_telefono.get()
        mail_cli = entCli_mail.get()
        direccion_cli = entCli_direccion.get()

        with sqlite3.connect("H2_SGE_1T_AitorBarriosGarcia.db") as conn:
            cursor = conn.cursor()

            cursor.execute("INSERT INTO cliente (id,nombre,apellido,telefono,mail,direccion) VALUES (?,?,?,?,?,?)",(id_cli,nombre_cli,apellido_cli,telefono_cli,mail_cli,direccion_cli))
            conn.commit()
            mostrar_reg()
            messagebox.showinfo("✔","Categoría Creada")

    def leer_reg():
        with sqlite3.connect("H2_SGE_1T_AitorBarriosGarcia.db") as conn:
            cursor = conn.cursor()
            cursor.execute("SELECT * FROM cliente")
            registros = cursor.fetchall()
        return registros
    
    def mostrar_reg():
        lista_reg.delete(*lista_reg.get_children())
        for registro in leer_reg():
            lista_reg.insert("","end",values=registro)

    def eliminar_reg():
        seleccion = lista_reg.selection()
        if seleccion:

            id_seleccionado = lista_reg.item(seleccion, "values")[0]
            with sqlite3.connect("H2_SGE_1T_AitorBarriosGarcia.db") as conn:
                cursor = conn.cursor()

                cursor.execute("DELETE FROM cliente WHERE id = ?", id_seleccionado)
                conn.commit()
                mostrar_reg()
                messagebox.showinfo("✔", "Categoria Eliminada")

    def modificar_reg():
        seleccion = lista_reg.selection()
        if seleccion:
            id_select = lista_reg.item(seleccion,"values")[0]

            nuevo_id=entCli_id.get()
            nuevo_nombre=entCli_nombre.get()
            nuevo_apellido=entCli_apellido.get()
            nuevo_telefono=entCli_telefono.get()
            nuevo_mail=entCli_mail.get()
            nuevo_direccion=entCli_direccion.get()

            with sqlite3.connect("H2_SGE_1T_AitorBarriosGarcia.db") as conn:
                cursor = conn.cursor()

                try:
                    cursor.execute("UPDATE cliente SET id=?,nombre=?,apellido=?,telefono=?,mail=?,direccion=? where id=?",
                                    (nuevo_id,nuevo_nombre,nuevo_apellido,nuevo_telefono,nuevo_mail,nuevo_direccion,id_select))
                    conn.commit()
                    mostrar_reg()
                    messagebox.showinfo("✔","Categoria Modificada")
                except sqlite3.Error as e:
                    messagebox.showerror("❌",f"No se pudo modificar: {e}")

    vCli = tk.Toplevel(ventana)
    vCli.title("Cliente")
    vCli.resizable(False,False)
    vCli.geometry("800x800")

    lblCli_id = tk.Label(vCli,text="ID")
    lblCli_id.grid(row=0,column=0,padx=10,pady=10)
    entCli_id = tk.Entry(vCli)
    entCli_id.grid(row=0,column=1)

    lblCli_nombre = tk.Label(vCli,text="Nombre")
    lblCli_nombre.grid(row=1,column=0,padx=10,pady=10)
    entCli_nombre = tk.Entry(vCli)
    entCli_nombre.grid(row=1,column=1)

    lblCli_apellido = tk.Label(vCli,text="Apellido")
    lblCli_apellido.grid(row=2,column=0,padx=10,pady=10)
    entCli_apellido = tk.Entry(vCli)
    entCli_apellido.grid(row=2,column=1)

    lblCli_telefono = tk.Label(vCli,text="Telefono")
    lblCli_telefono.grid(row=3,column=0,padx=10,pady=10)
    entCli_telefono = tk.Entry(vCli)
    entCli_telefono.grid(row=3,column=1)

    lblCli_mail = tk.Label(vCli,text="Mail")
    lblCli_mail.grid(row=4,column=0,padx=10,pady=10)
    entCli_mail = tk.Entry(vCli)
    entCli_mail.grid(row=4,column=1)

    lblCli_direccion = tk.Label(vCli,text="Dirección")
    lblCli_direccion.grid(row=5,column=0,padx=10,pady=10)
    entCli_direccion = tk.Entry(vCli)
    entCli_direccion.grid(row=5,column=1)

    bt_crear = tk.Button(vCli,text="Crear",command=crear_reg)
    bt_crear.grid(row=6,column=0,padx=10,pady=10)
    bt_eliminar = tk.Button(vCli,text="Eliminar",command=eliminar_reg)
    bt_eliminar.grid(row=7,column=0,padx=10,pady=10)
    bt_modificar = tk.Button(vCli,text="Modificar",command=modificar_reg)
    bt_modificar.grid(row=8,column=0,padx=10,pady=10)

    lista_reg = ttk.Treeview(vCli,columns=("ID","Nombre","Apellido","Telefono","Mail","Direccion"),show="headings",selectmode="browse")
    lista_reg.heading("ID",text="ID")
    lista_reg.heading("Nombre",text="Nombre")
    lista_reg.heading("Apellido",text="Apellido")
    lista_reg.heading("Telefono",text="Telefono")
    lista_reg.heading("Mail",text="Mail")
    lista_reg.heading("Direccion",text="Direccion")
    lista_reg.column("ID",width=90)
    lista_reg.column("Nombre",width=90)
    lista_reg.column("Apellido",width=90)
    lista_reg.column("Telefono",width=90)
    lista_reg.column("Mail",width=90)
    lista_reg.column("Direccion",width=90)
    estilo=ttk.Style()
    estilo.configure("Treeview",background="gray",foreground="blue",rowheight=25)
    estilo.map("Treeview",background=[('selected','#cc007b')])
    lista_reg.grid(row=0, column=2, rowspan=6, padx=10, pady=10, sticky="nsew")
    scrollbar = Scrollbar(vCli, orient="vertical", command=lista_reg.yview)
    scrollbar.grid(row=0, column=3, rowspan=6, sticky="ns")
    lista_reg.configure(yscrollcommand=scrollbar.set)

    mostrar_reg()
    vCli.mainloop()

def vPro():
    def crear_reg():
        id_Pro = entPro_id.get()
        nombre_Pro = entPro_nombre.get()
        stock_Pro = entPro_stock.get()
        precio_Pro = entPro_precio.get()
        idcat_Pro = entPro_idcategoria.get()

        with sqlite3.connect("H2_SGE_1T_AitorBarriosGarcia.db") as conn:
            cursor = conn.cursor()

            cursor.execute("INSERT INTO producto (id,nombre,stock,precio,idcat) VALUES (?,?,?,?,?)",(id_Pro,nombre_Pro,stock_Pro,precio_Pro,idcat_Pro))
            conn.commit()
            mostrar_reg()
            messagebox.showinfo("✔","Categoría Creada")

    def leer_reg():
        with sqlite3.connect("H2_SGE_1T_AitorBarriosGarcia.db") as conn:
            cursor = conn.cursor()
            cursor.execute("SELECT * FROM producto")
            registros = cursor.fetchall()
        return registros
    
    def mostrar_reg():
        lista_reg.delete(*lista_reg.get_children())
        for registro in leer_reg():
            lista_reg.insert("","end",values=registro)

    def eliminar_reg():
        seleccion = lista_reg.selection()
        if seleccion:

            id_seleccionado = lista_reg.item(seleccion, "values")[0]
            with sqlite3.connect("H2_SGE_1T_AitorBarriosGarcia.db") as conn:
                cursor = conn.cursor()

                cursor.execute("DELETE FROM producto WHERE id = ?", id_seleccionado)
                conn.commit()
                mostrar_reg()
                messagebox.showinfo("✔", "Categoria Eliminada")

    def modificar_reg():
        seleccion = lista_reg.selection()
        if seleccion:
            id_select = lista_reg.item(seleccion,"values")[0]

            nuevo_id=entPro_id.get()
            nuevo_nombre=entPro_nombre.get()
            nuevo_stock=entPro_stock.get()
            nuevo_precio=entPro_precio.get()
            nuevo_idcat=entPro_idcategoria.get()

            with sqlite3.connect("H2_SGE_1T_AitorBarriosGarcia.db") as conn:
                cursor = conn.cursor()

                try:
                    cursor.execute("UPDATE producto SET id=?,nombre=?,stock=?,precio=?,idcat=? where id=?",
                                    (nuevo_id,nuevo_nombre,nuevo_stock,nuevo_precio,nuevo_idcat,id_select))
                    conn.commit()
                    mostrar_reg()
                    messagebox.showinfo("✔","Categoria Modificada")
                except sqlite3.Error as e:
                    messagebox.showerror("❌",f"No se pudo modificar: {e}")

    vPro = tk.Toplevel(ventana)
    vPro.title("Producto")
    vPro.resizable(False,False)
    vPro.geometry("800x800")

    lblPro_id = tk.Label(vPro,text="ID")
    lblPro_id.grid(row=0,column=0,padx=10,pady=10)
    entPro_id = tk.Entry(vPro)
    entPro_id.grid(row=0,column=1)

    lblPro_nombre = tk.Label(vPro,text="Nombre")
    lblPro_nombre.grid(row=1,column=0,padx=10,pady=10)
    entPro_nombre = tk.Entry(vPro)
    entPro_nombre.grid(row=1,column=1)

    lblPro_stock = tk.Label(vPro,text="Stock")
    lblPro_stock.grid(row=2,column=0,padx=10,pady=10)
    entPro_stock = tk.Entry(vPro)
    entPro_stock.grid(row=2,column=1)

    lblPro_precio = tk.Label(vPro,text="Precio")
    lblPro_precio.grid(row=3,column=0,padx=10,pady=10)
    entPro_precio = tk.Entry(vPro)
    entPro_precio.grid(row=3,column=1)

    lblPro_idcategoria = tk.Label(vPro,text="ID Categoria")
    lblPro_idcategoria.grid(row=4,column=0,padx=10,pady=10)
    entPro_idcategoria = tk.Entry(vPro)
    entPro_idcategoria.grid(row=4,column=1)

    bt_crear = tk.Button(vPro,text="Crear",command=crear_reg)
    bt_crear.grid(row=5,column=0,padx=10,pady=10)
    bt_eliminar = tk.Button(vPro,text="Eliminar",command=eliminar_reg)
    bt_eliminar.grid(row=6,column=0,padx=10,pady=10)
    bt_modificar = tk.Button(vPro,text="Modificar",command=modificar_reg)
    bt_modificar.grid(row=7,column=0,padx=10,pady=10)

    lista_reg = ttk.Treeview(vPro,columns=("ID","Nombre","Stock","Precio","ID Categoria"),show="headings",selectmode="browse")
    lista_reg.heading("ID",text="ID")
    lista_reg.heading("Nombre",text="Nombre")
    lista_reg.heading("Stock",text="Stock")
    lista_reg.heading("Precio",text="Precio")
    lista_reg.heading("ID Categoria",text="ID Categoria")
    lista_reg.column("ID",width=80)
    lista_reg.column("Nombre",width=80)
    lista_reg.column("Stock",width=80)
    lista_reg.column("Precio",width=80)
    lista_reg.column("ID Categoria",width=80)
    estilo=ttk.Style()
    estilo.configure("Treeview",background="gray",foreground="blue",rowheight=25)
    estilo.map("Treeview",background=[('selected','#cc007b')])
    lista_reg.grid(row=0, column=2, rowspan=6, padx=10, pady=10, sticky="nsew")
    scrollbar = Scrollbar(vPro, orient="vertical", command=lista_reg.yview)
    scrollbar.grid(row=0, column=3, rowspan=6, sticky="ns")
    lista_reg.configure(yscrollcommand=scrollbar.set)

    mostrar_reg()
    vPro.mainloop()

def vPed():
    def crear_reg():
        id_Ped = entPed_id.get()
        idcli_Ped = entPed_idcliente.get()
        idpro_Ped = entPed_idproducto.get()
        fecha_Ped = entPed_fecha.get()

        with sqlite3.connect("H2_SGE_1T_AitorBarriosGarcia.db") as conn:
            cursor = conn.cursor()

            cursor.execute("INSERT INTO pedido (id,idcliente,idproducto,fecha) VALUES (?,?,?,?)",(id_Ped,idcli_Ped,idpro_Ped,fecha_Ped))
            conn.commit()
            mostrar_reg()
            messagebox.showinfo("✔","Pedido Creado")

    def leer_reg():
        with sqlite3.connect("H2_SGE_1T_AitorBarriosGarcia.db") as conn:
            cursor = conn.cursor()
            cursor.execute("SELECT * FROM pedido")
            registros = cursor.fetchall()
        return registros
    
    def mostrar_reg():
        lista_reg.delete(*lista_reg.get_children())
        for registro in leer_reg():
            lista_reg.insert("","end",values=registro)

    def eliminar_reg():
        seleccion = lista_reg.selection()
        if seleccion:

            id_seleccionado = lista_reg.item(seleccion, "values")[0]
            with sqlite3.connect("H2_SGE_1T_AitorBarriosGarcia.db") as conn:
                cursor = conn.cursor()

                cursor.execute("DELETE FROM pedido WHERE id = ?", id_seleccionado)
                conn.commit()
                mostrar_reg()
                messagebox.showinfo("✔", "Pedido Eliminado")

    def modificar_reg():
        seleccion = lista_reg.selection()
        if seleccion:
            id_select = lista_reg.item(seleccion,"values")[0]

            nuevo_id=entPed_id.get()
            nuevo_idcli=entPed_idcliente.get()
            nuevo_idprod=entPed_idproducto.get()
            nuevo_fecha=entPed_fecha.get()

            with sqlite3.connect("H2_SGE_1T_AitorBarriosGarcia.db") as conn:
                cursor = conn.cursor()

                try:
                    cursor.execute("UPDATE pedido SET id=?,idcliente=?,idproducto=?,fecha=? where id=?",
                                    (nuevo_id,nuevo_idcli,nuevo_idprod,nuevo_fecha,id_select))
                    conn.commit()
                    mostrar_reg()
                    messagebox.showinfo("✔","Pedido Modificado")
                except sqlite3.Error as e:
                    messagebox.showerror("❌",f"No se pudo modificar: {e}")

    vPed = tk.Toplevel(ventana)
    vPed.title("Pedido")
    vPed.resizable(False,False)
    vPed.geometry("800x800")

    lblPed_id = tk.Label(vPed,text="ID")
    lblPed_id.grid(row=0,column=0,padx=10,pady=10)
    entPed_id = tk.Entry(vPed)
    entPed_id.grid(row=0,column=1)

    lblPed_idcliente = tk.Label(vPed,text="ID Cliente")
    lblPed_idcliente.grid(row=1,column=0,padx=10,pady=10)
    entPed_idcliente = tk.Entry(vPed)
    entPed_idcliente.grid(row=1,column=1)

    lblPed_idproducto = tk.Label(vPed,text="ID Producto")
    lblPed_idproducto.grid(row=2,column=0,padx=10,pady=10)
    entPed_idproducto = tk.Entry(vPed)
    entPed_idproducto.grid(row=2,column=1)

    lblPed_fecha = tk.Label(vPed,text="Fecha")
    lblPed_fecha.grid(row=3,column=0,padx=10,pady=10)
    entPed_fecha = tk.Entry(vPed)
    entPed_fecha.grid(row=3,column=1)

    bt_crear = tk.Button(vPed,text="Crear",command=crear_reg)
    bt_crear.grid(row=4,column=0,padx=10,pady=10)
    bt_eliminar = tk.Button(vPed,text="Eliminar",command=eliminar_reg)
    bt_eliminar.grid(row=5,column=0,padx=10,pady=10)
    bt_modificar = tk.Button(vPed,text="Modificar",command=modificar_reg)
    bt_modificar.grid(row=6,column=0,padx=10,pady=10)

    lista_reg = ttk.Treeview(vPed,columns=("ID","ID Cliente","ID Producto","Fecha"),show="headings",selectmode="browse")
    lista_reg.heading("ID",text="ID")
    lista_reg.heading("ID Cliente",text="ID Cliente")
    lista_reg.heading("ID Producto",text="ID Producto")
    lista_reg.heading("Fecha",text="Fecha")
    lista_reg.column("ID",width=80)
    lista_reg.column("ID Cliente",width=80)
    lista_reg.column("ID Producto",width=80)
    lista_reg.column("Fecha",width=80)
    estilo=ttk.Style()
    estilo.configure("Treeview",background="gray",foreground="blue",rowheight=25)
    estilo.map("Treeview",background=[('selected','#cc007b')])
    lista_reg.grid(row=0, column=2, rowspan=6, padx=10, pady=10, sticky="nsew")
    scrollbar = Scrollbar(vPed, orient="vertical", command=lista_reg.yview)
    scrollbar.grid(row=0, column=3, rowspan=6, sticky="ns")
    lista_reg.configure(yscrollcommand=scrollbar.set)

    mostrar_reg()
    vPed.mainloop()

def vDet():
    def crear_reg():
        id_Det = entDet_id.get()
        idcli_Det = entDet_idcliente.get()
        idped_Det = entDet_idpedido.get()
        cantidad_Det = entDet_cantidad.get()

        with sqlite3.connect("H2_SGE_1T_AitorBarriosGarcia.db") as conn:
            cursor = conn.cursor()

            cursor.execute("INSERT INTO detalle (id,idcliente,idpedido,cantidad) VALUES (?,?,?,?)",(id_Det,idcli_Det,idped_Det,cantidad_Det))
            conn.commit()
            mostrar_reg()
            messagebox.showinfo("✔","Detalle Creado")

    def leer_reg():
        with sqlite3.connect("H2_SGE_1T_AitorBarriosGarcia.db") as conn:
            cursor = conn.cursor()
            cursor.execute("SELECT * FROM detalle")
            registros = cursor.fetchall()
        return registros
    
    def mostrar_reg():
        lista_reg.delete(*lista_reg.get_children())
        for registro in leer_reg():
            lista_reg.insert("","end",values=registro)

    def eliminar_reg():
        seleccion = lista_reg.selection()
        if seleccion:

            id_seleccionado = lista_reg.item(seleccion, "values")[0]
            with sqlite3.connect("H2_SGE_1T_AitorBarriosGarcia.db") as conn:
                cursor = conn.cursor()

                cursor.execute("DELETE FROM detalle WHERE id = ?", id_seleccionado)
                conn.commit()
                mostrar_reg()
                messagebox.showinfo("✔", "Detalle Eliminado")

    def modificar_reg():
        seleccion = lista_reg.selection()
        if seleccion:
            id_select = lista_reg.item(seleccion,"values")[0]

            nuevo_id=entDet_id.get()
            nuevo_idcli=entDet_idcliente.get()
            nuevo_idped=entDet_idpedido.get()
            nuevo_cantidad=entDet_cantidad.get()

            with sqlite3.connect("H2_SGE_1T_AitorBarriosGarcia.db") as conn:
                cursor = conn.cursor()

                try:
                    cursor.execute("UPDATE detalle SET id=?,idcliente=?,idpedido=?,cantidad=? where id=?",
                                    (nuevo_id,nuevo_idcli,nuevo_idped,nuevo_cantidad,id_select))
                    conn.commit()
                    mostrar_reg()
                    messagebox.showinfo("✔","Pedido Modificado")
                except sqlite3.Error as e:
                    messagebox.showerror("❌",f"No se pudo modificar: {e}")

    vDet = tk.Toplevel(ventana)
    vDet.title("Detalle")
    vDet.resizable(False,False)
    vDet.geometry("800x800")

    lblDet_id = tk.Label(vDet,text="ID")
    lblDet_id.grid(row=0,column=0,padx=10,pady=10)
    entDet_id = tk.Entry(vDet)
    entDet_id.grid(row=0,column=1)

    lblDet_idcliente = tk.Label(vDet,text="ID Cliente")
    lblDet_idcliente.grid(row=1,column=0,padx=10,pady=10)
    entDet_idcliente = tk.Entry(vDet)
    entDet_idcliente.grid(row=1,column=1)

    lblDet_idpedido = tk.Label(vDet,text="ID Pedido")
    lblDet_idpedido.grid(row=2,column=0,padx=10,pady=10)
    entDet_idpedido = tk.Entry(vDet)
    entDet_idpedido.grid(row=2,column=1)

    lblDet_cantidad = tk.Label(vDet,text="Cantidad")
    lblDet_cantidad.grid(row=3,column=0,padx=10,pady=10)
    entDet_cantidad = tk.Entry(vDet)
    entDet_cantidad.grid(row=3,column=1)

    bt_crear = tk.Button(vDet,text="Crear",command=crear_reg)
    bt_crear.grid(row=4,column=0,padx=10,pady=10)
    bt_eliminar = tk.Button(vDet,text="Eliminar",command=eliminar_reg)
    bt_eliminar.grid(row=5,column=0,padx=10,pady=10)
    bt_modificar = tk.Button(vDet,text="Modificar",command=modificar_reg)
    bt_modificar.grid(row=6,column=0,padx=10,pady=10)

    lista_reg = ttk.Treeview(vDet,columns=("ID","ID Cliente","ID Pedido","Cantidad"),show="headings",selectmode="browse")
    lista_reg.heading("ID",text="ID")
    lista_reg.heading("ID Cliente",text="ID Cliente")
    lista_reg.heading("ID Pedido",text="ID Pedido")
    lista_reg.heading("Cantidad",text="Cantidad")
    lista_reg.column("ID",width=80)
    lista_reg.column("ID Cliente",width=80)
    lista_reg.column("ID Pedido",width=80)
    lista_reg.column("Cantidad",width=80)
    estilo=ttk.Style()
    estilo.configure("Treeview",background="gray",foreground="blue",rowheight=25)
    estilo.map("Treeview",background=[('selected','#cc007b')])
    lista_reg.grid(row=0, column=2, rowspan=6, padx=10, pady=10, sticky="nsew")
    scrollbar = Scrollbar(vDet, orient="vertical", command=lista_reg.yview)
    scrollbar.grid(row=0, column=3, rowspan=6, sticky="ns")
    lista_reg.configure(yscrollcommand=scrollbar.set)

    mostrar_reg()
    vDet.mainloop()

#VENTANA PRINCIPAL, command=ventana
bt_CATEGORIA = tk.Button(ventana, height=100, width=100, command=vCat, image=cat)#
bt_CATEGORIA.grid(row=0,column=0, padx=10, pady=10)
lbl_CATEGORIA = tk.Label(ventana,text="Categoría", font=("Algerian",15))
lbl_CATEGORIA.grid(row=1,column=0, padx=10,pady=10)

bt_CLIENTE = tk.Button(ventana, height=100, width=100, command=vCli, image=cli)#
bt_CLIENTE.grid(row=0,column=1, padx=10, pady=10)
lbl_CLIENTE = tk.Label(ventana,text="Cliente", font=("Algerian",15))
lbl_CLIENTE.grid(row=1,column=1, padx=10,pady=10)

bt_PRODUCTO = tk.Button(ventana, height=100, width=100, command=vPro, image=pro)#
bt_PRODUCTO.grid(row=0,column=2, padx=10, pady=10)
lbl_PRODUCTO = tk.Label(ventana,text="Producto", font=("Algerian",15))
lbl_PRODUCTO.grid(row=1,column=2, padx=10,pady=10)

bt_PEDIDO = tk.Button(ventana, height=100, width=100, command=vPed, image=ped)#
bt_PEDIDO.grid(row=0,column=3, padx=10, pady=10)
lbl_PEDIDO = tk.Label(ventana,text="Pedido", font=("Algerian",15))
lbl_PEDIDO.grid(row=1,column=3, padx=10,pady=10)

bt_DETALLE = tk.Button(ventana, height=100, width=100, command=vDet, image=det)#
bt_DETALLE.grid(row=0,column=4, padx=10, pady=10)
lbl_DETALLE = tk.Label(ventana,text="Detalle", font=("Algerian",15))
lbl_DETALLE.grid(row=1,column=4, padx=10,pady=10)

#MUESTRA LA VENTANA
ventana.mainloop()

# %%
import customtkinter as ctk
from PIL import Image

ventana = ctk.CTk()
ventana.title("H2_SistemasGestionEmpresarial_1T_AitorBarriosGarcía")
ventana.resizable(False,False)
ventana.geometry("400x400")

cat = ctk.CTkImage(light_image=Image.open("G://Mi unidad//2ºDAM//Sistemas de Gestión Empresarial//HITOS//H2_SistemasGestionEmpresarial_1T_Aitor_BarriosGarcia//img//categoria.png"),dark_image=Image.open("G://Mi unidad//2ºDAM//Sistemas de Gestión Empresarial//HITOS//H2_SistemasGestionEmpresarial_1T_Aitor_BarriosGarcia//img//categoria.png"),size=(50,50))
cli = ctk.CTkImage(light_image=Image.open("G://Mi unidad//2ºDAM//Sistemas de Gestión Empresarial//HITOS//H2_SistemasGestionEmpresarial_1T_Aitor_BarriosGarcia//img//cliente.png"),dark_image=Image.open("G://Mi unidad//2ºDAM//Sistemas de Gestión Empresarial//HITOS//H2_SistemasGestionEmpresarial_1T_Aitor_BarriosGarcia//img//cliente.png"),size=(80,60))
pro = ctk.CTkImage(light_image=Image.open("G://Mi unidad//2ºDAM//Sistemas de Gestión Empresarial//HITOS//H2_SistemasGestionEmpresarial_1T_Aitor_BarriosGarcia//img//producto.png"),dark_image=Image.open("G://Mi unidad//2ºDAM//Sistemas de Gestión Empresarial//HITOS//H2_SistemasGestionEmpresarial_1T_Aitor_BarriosGarcia//img//producto.png"),size=(50,50))
ped = ctk.CTkImage(light_image=Image.open("G://Mi unidad//2ºDAM//Sistemas de Gestión Empresarial//HITOS//H2_SistemasGestionEmpresarial_1T_Aitor_BarriosGarcia//img//pedido.png"),dark_image=Image.open("G://Mi unidad//2ºDAM//Sistemas de Gestión Empresarial//HITOS//H2_SistemasGestionEmpresarial_1T_Aitor_BarriosGarcia//img//pedido.png"),size=(50,50))
det = ctk.CTkImage(light_image=Image.open("G://Mi unidad//2ºDAM//Sistemas de Gestión Empresarial//HITOS//H2_SistemasGestionEmpresarial_1T_Aitor_BarriosGarcia//img//detalle.png"),dark_image=Image.open("G://Mi unidad//2ºDAM//Sistemas de Gestión Empresarial//HITOS//H2_SistemasGestionEmpresarial_1T_Aitor_BarriosGarcia//img//detalle.png"),size=(50,50))

bt_CATEGORIA = ctk.CTkButton(ventana, height=100, width=100,image=cat,text="")#, command=vCat 
bt_CATEGORIA.grid(row=0,column=0, padx=10, pady=10)
lbl_CATEGORIA = ctk.CTkLabel(ventana,text="Categoría", font=("Algerian",15))
lbl_CATEGORIA.grid(row=1,column=0, padx=10,pady=10)

bt_CLIENTE = ctk.CTkButton(ventana, height=100, width=100,image=cli,text="")#, command=vCli 
bt_CLIENTE.grid(row=0,column=1, padx=10, pady=10)
lbl_CLIENTE = ctk.CTkLabel(ventana,text="Cliente", font=("Algerian",15))
lbl_CLIENTE.grid(row=1,column=1, padx=10,pady=10)

bt_PRODUCTO = ctk.CTkButton(ventana, height=100, width=100,image=pro,text="")#, command=vPro 
bt_PRODUCTO.grid(row=0,column=2, padx=10, pady=10)
lbl_PRODUCTO = ctk.CTkLabel(ventana,text="Producto", font=("Algerian",15))
lbl_PRODUCTO.grid(row=1,column=2, padx=10,pady=10)

bt_PEDIDO = ctk.CTkButton(ventana, height=100, width=100,image=ped,text="")#, command=vPed 
bt_PEDIDO.grid(row=2,column=0, padx=10, pady=10)
lbl_PEDIDO = ctk.CTkLabel(ventana,text="Pedido", font=("Algerian",15))
lbl_PEDIDO.grid(row=3,column=0, padx=10,pady=10)

bt_DETALLE = ctk.CTkButton(ventana, height=100, width=100,image=det,text="")#, command=vDet 
bt_DETALLE.grid(row=2,column=1, padx=10, pady=10)
lbl_DETALLE = ctk.CTkLabel(ventana,text="Detalle", font=("Algerian",15))
lbl_DETALLE.grid(row=3,column=1, padx=10,pady=10)


ventana.mainloop()
# Out:
# ---------------------------------------------------------------------------
# TclError                                  Traceback (most recent call last)
# g:\Mi unidad\2ºDAM\Sistemas de Gestión Empresarial\HITOS\H2_SistemasGestionEmpresarial_1T_Aitor_BarriosGarcia\H2_SistemasGestionEmpresarial_1T_AitorBarriosGarcía.ipynb Cell 2 line 1
#      <a href='vscode-notebook-cell:/g%3A/Mi%20unidad/2%C2%BADAM/Sistemas%20de%20Gesti%C3%B3n%20Empresarial/HITOS/H2_SistemasGestionEmpresarial_1T_Aitor_BarriosGarcia/H2_SistemasGestionEmpresarial_1T_AitorBarriosGarc%C3%ADa.ipynb#W1sZmlsZQ%3D%3D?line=11'>12</a> ped = ctk.CTkImage(light_image=Image.open("G://Mi unidad//2ºDAM//Sistemas de Gestión Empresarial//HITOS//H2_SistemasGestionEmpresarial_1T_Aitor_BarriosGarcia//img//pedido.png"),dark_image=Image.open("G://Mi unidad//2ºDAM//Sistemas de Gestión Empresarial//HITOS//H2_SistemasGestionEmpresarial_1T_Aitor_BarriosGarcia//img//pedido.png"),size=(50,50))
# ...
